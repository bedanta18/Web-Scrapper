# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://vahan.parivahan.gov.in/vahan4dashboard/vahan/view/reportview.xhtml"

# %%
headers = {'Cookie': 'JSESSIONID=8F824884B1A9AA58406CC96D73ACC7BD; SERVERID=vahan_ser89_139','User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}

# %%
#session = requests.Session()

# %%
response = requests.get(url, headers=headers)

# %%
query = 'Vehicle Class'

# %%
soup = BeautifulSoup(response.content,"lxml")

# %%
#print(soup.prettify())

# %%
table = soup.find("input",id = 'j_id1:javax.faces.ViewState:0')['value']

# %%
print(table)
# Out:
# ...

# %%
data = {
    'javax.faces.partial.ajax': True,
    'javax.faces.source': 'irclay',
    'javax.faces.partial.execute': '@all',
    'javax.faces.partial.render': 'tablePnl',
    'irclay': 'irclay',
    'masterLayout_formlogin': 'masterLayout_formlogin',
    'j_idt23_focus': '',
    'j_idt23_input': 'A',
    'j_idt31_focus': '',
    'j_idt31_input': '-1',
    'selectedRto_focus': '',
    'selectedRto_input': '-1',
    'yaxisVar_focus': '',
    'yaxisVar_input': query,
    'xaxisVar_focus': '',
    'xaxisVar_input': 'Vehicle Category',
    'selectedYearType_focus': '',
    'selectedYearType_input': 'C',
    'selectedYear_focus': '',
    'selectedYear_input': '2019',
    'groupingTable_scrollState': '0,0' ,
    'javax.faces.ViewState': table}

# %%
response1 = requests.post(url,data=data,headers=headers)

# %%
print(response1)
# Out:
# <Response [200]>

# %%
info = BeautifulSoup(response1.content,"html.parser")

# %%
print(info)
# Out:
# <?xml version='1.0' encoding='UTF-8'?>
# ...

# %%
print('\n')

# %%
print(info.get_text())
# Out:
# <div id="tablePnl" class="ui-outputpanel ui-widget"><div id="j_idt65" style="min-width:400px;min-height:710px; border: 0 !important"><div id="filterLayout" class="ui-layout-unit ui-widget ui-widget-content ui-corner-all ui-layout-west"><div class="ui-layout-unit-header ui-widget-header ui-corner-all"><span class="ui-layout-unit-header-title"><button id="j_idt66" name="j_idt66" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-icon-left" onclick="PrimeFaces.ab({s:&quot;j_idt66&quot;,f:&quot;masterLayout_formlogin&quot;,u:&quot;combTablePnl&quot;,onst:function(cfg){PF('blockpnlCombTable').show();},onco:function(xhr,status,args){PF('blockpnlCombTable').hide();}});return false;" style="margin: 2px !important; border-radius: 5px;" type="submit"><span class="ui-button-icon-left ui-icon ui-c ui-icon-refresh"></span><span class="ui-button-text ui-c">Refresh</span></button><script id="j_idt66_s" type="text/javascript">PrimeFaces.cw("CommandButton","widget_j_idt66",{id:"
# ...
